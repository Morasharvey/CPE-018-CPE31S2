# %% [markdown]
# <a href="https://colab.research.google.com/github/Morasharvey/CPE-018-CPE31S2/blob/main/Moras_PrelimExam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #31
#
# 1. Open the uploaded file in Question 31Links to an external site.
#
# 2. Write a Python script using OpenCV that:

# %% [markdown]
# Reads an image named "nature.jpg"

# %%
import cv2
import numpy as np

cv2.imread('nature.jpg')
# Out:
# array([[[125, 147, 172],
#         [125, 149, 171],
#         [128, 154, 171],
#         ...,
#         [160, 119,   3],
#         [160, 119,   3],
#         [160, 119,   3]],
#
#        [[127, 149, 174],
#         [127, 151, 173],
#         [129, 155, 172],
#         ...,
#         [160, 120,   2],
#         [160, 120,   2],
#         [160, 120,   2]],
#
#        [[130, 153, 175],
#         [131, 155, 175],
#         [131, 157, 173],
#         ...,
#         [161, 121,   3],
#         [161, 121,   3],
#         [161, 121,   3]],
#
#        ...,
#
#        [[  0,   7,   0],
#         [ 15,   3,   0],
#         [ 45,  27,   4],
#         ...,
#         [ 47,  26,   4],
#         [ 46,  25,   3],
#         [ 45,  24,   3]],
#
#        [[ 13,  17,   6],
#         [ 70,  60,   0],
#         [106,  92,   3],
#         ...,
#         [ 51,  32,   5],
#         [ 50,  31,   4],
#         [ 49,  30,   3]],
#
#        [[ 28,   9,  18],
#         [108,  82,  12],
#         [117,  85,  10],
# ...

# %% [markdown]
#  Converts it to grayscale

# %%
cv2.cvtColor(cv2.imread('nature.jpg'),cv2.COLOR_BGR2GRAY)
# Out:
# array([[152, 153, 156, ...,  89,  89,  89],
#        [154, 155, 157, ...,  89,  89,  89],
#        [157, 158, 159, ...,  90,  90,  90],
#        ...,
#        [  4,   3,  22, ...,  22,  21,  20],
#        [ 13,  43,  67, ...,  26,  25,  24],
#        [ 14,  64,  66, ...,  33,  31,  28]], dtype=uint8)

# %% [markdown]
# Resizes it to 300x300 pixels

# %%
cv2.cvtColor(cv2.resize(cv2.imread('nature.jpg'),(300,300)),cv2.COLOR_BGR2GRAY)
# Out:
# array([[153, 156, 159, ...,  89,  89,  89],
#        [155, 158, 161, ...,  91,  89,  89],
#        [158, 160, 163, ...,  92,  91,  91],
#        ...,
#        [  4,  16,  14, ...,  38,  23,  19],
#        [ 19,  54,   9, ...,  32,  25,  23],
#        [ 33,  59,   1, ...,  26,  33,  29]], dtype=uint8)

# %% [markdown]
# Saves the result as "processed.jpg"

# %%
cv2.imwrite('processed.jpg', processed_image)
# Out:
# True

# %% [markdown]
# #32
# You have an image named circles.png containing various circles  circlesLinks to an external site. of different sizes. Write a Python script using OpenCV that:
#
# Load and preprocess the image
# Detect circles using Hough Circle Transform
# Draw detected circles in red color
# Save the result as circles_detected.png

# %% [markdown]
# Load and preprocess the image

# %%
import cv2
import numpy as np

n = 5
planets = cv2.imread('circles.png')

# %% [markdown]
# Detect circles using Hough Circle Transform

# %%
gray_img = cv2.cvtColor(planets, cv2.COLOR_BGR2GRAY)

cimg = cv2.cvtColor(img, cv2.COLOR_GRAY2BGR)

circles = cv2.HoughCircles
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-3373289154.py in <cell line: 0>()
#       1 gray_img = cv2.cvtColor(planets, cv2.COLOR_BGR2GRAY)
#       2
# ----> 3 cimg = cv2.cvtColor(img.cv2.HOUGH_GRADIENT,1,120, param1 = 69,param2=30,minRadius=0,maxRadius=0)
#       4
#
# AttributeError: 'numpy.ndarray' object has no attribute 'cv2'
